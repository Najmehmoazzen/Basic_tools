# %%
import numpy as np

# %%
A = np.zeros(1, dtype=int)
A[0]=2
for i in range (3,100,1):
    for j in range (0,len(A),1):
        if i%A[j]==0:
            print (i,"is Morakab")
            break
    if i%A[j]!=0:
        print (i,"is Aval")
        A = np.append(A,i)
# Out:
# 3 is Aval
# 4 is Morakab
# 5 is Aval
# 6 is Morakab
# 7 is Aval
# 8 is Morakab
# 9 is Morakab
# 10 is Morakab
# 11 is Aval
# 12 is Morakab
# 13 is Aval
# 14 is Morakab
# 15 is Morakab
# 16 is Morakab
# 17 is Aval
# 18 is Morakab
# 19 is Aval
# 20 is Morakab
# 21 is Morakab
# 22 is Morakab
# 23 is Aval
# 24 is Morakab
# 25 is Morakab
# 26 is Morakab
# 27 is Morakab
# 28 is Morakab
# 29 is Aval
# 30 is Morakab
# 31 is Aval
# 32 is Morakab
# 33 is Morakab
# 34 is Morakab
# 35 is Morakab
# 36 is Morakab
# 37 is Aval
# 38 is Morakab
# 39 is Morakab
# 40 is Morakab
# 41 is Aval
# 42 is Morakab
# 43 is Aval
# 44 is Morakab
# 45 is Morakab
# 46 is Morakab
# 47 is Aval
# 48 is Morakab
# 49 is Morakab
# 50 is Morakab
# 51 is Morakab
# 52 is Morakab
# 53 is Aval
# 54 is Morakab
# 55 is Morakab
# 56 is Morakab
# 57 is Morakab
# 58 is Morakab
# 59 is Aval
# 60 is Morakab
# 61 is Aval
# 62 is Morakab
# 63 is Morakab
# 64 is Morakab
# 65 is Morakab
# 66 is Morakab
# 67 is Aval
# 68 is Morakab
# ...
